# %% [markdown]
# https://www.youtube.com/watch?v=06TE_U21FK4
#
# GET THE CODE FROM THE VIDEO:
# https://github.com/nicknochnack/MediaPipePoseEstimation

# %% [markdown]
# # 0. Install and Import Dependencies

# %%
# !pip install mediapipe opencv-python
# Out:
# Requirement already satisfied: mediapipe in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (0.9.1.0)
# Requirement already satisfied: opencv-python in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (4.8.1.78)
# Requirement already satisfied: absl-py in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from mediapipe) (2.0.0)
# Requirement already satisfied: attrs>=19.1.0 in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: matplotlib in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from mediapipe) (3.8.2)
# Requirement already satisfied: numpy in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from mediapipe) (1.26.2)
# Requirement already satisfied: opencv-contrib-python in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from mediapipe) (4.8.1.78)
# Requirement already satisfied: protobuf<4,>=3.11 in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from matplotlib->mediapipe) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from matplotlib->mediapipe) (23.1)
# Requirement already satisfied: pillow>=8 in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from matplotlib->mediapipe) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from matplotlib->mediapipe) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->mediapipe) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/peilinyang/miniconda3/envs/mediapipe/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)

# %%
import cv2
import mediapipe as mp
import numpy as np
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
# Out:
# 2023-12-07 09:30:33.912072: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# VIDEO FEED
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    cv2.imshow('Mediapipe Feed', frame)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# 2023-12-07 09:30:40.603 python[70410:3762787] _TIPropertyValueIsValid called with 11 on nil context!
# 2023-12-07 09:30:40.603 python[70410:3762787] imkxpc_setApplicationProperty:value:reply: called with incorrect property value 11, bailing.
# 2023-12-07 09:30:40.603 python[70410:3762787] _TIPropertyValueIsValid called with 12 on nil context!
# 2023-12-07 09:30:40.603 python[70410:3762787] imkxpc_setApplicationProperty:value:reply: called with incorrect property value 12, bailing.
# 2023-12-07 09:30:45.536 python[70410:3762787] _TIPropertyValueIsValid called with 12 on nil context!
# 2023-12-07 09:30:45.536 python[70410:3762787] imkxpc_setApplicationProperty:value:reply: called with incorrect property value 12, bailing.

# %% [markdown]
# # 1. Make Detections

# %%
cap = cv2.VideoCapture(0)
## Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # Make detection
        results = pose.process(image)
    
        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Render detections(骨架)
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) 
                                 )               
        
        cv2.imshow('Mediapipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# # 2. Determining Joints

# %% [markdown]
# <img src="https://i.imgur.com/3j8BPdc.png" style="height:300px" >

# %%
cap = cv2.VideoCapture(0)
## Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # Make detection
        results = pose.process(image)
    
        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
            print(landmarks)
        except:
            pass
        
        
        # Render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) 
                                 )               
        
        cv2.imshow('Mediapipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# [x: 0.5388038158416748
# y: 0.23972028493881226
# z: -1.0592519044876099
# visibility: 0.9930329322814941
# , x: 0.5537376403808594
# y: 0.1986464560031891
# z: -1.036442756652832
# visibility: 0.9781136512756348
# , x: 0.5615512132644653
# y: 0.20056818425655365
# z: -1.0365242958068848
# visibility: 0.9797652363777161
# , x: 0.5693454742431641
# y: 0.20263907313346863
# z: -1.0366833209991455
# visibility: 0.9708376526832581
# , x: 0.5314065217971802
# y: 0.1922629177570343
# z: -1.040398359298706
# visibility: 0.981953501701355
# , x: 0.5234544277191162
# y: 0.1891224980354309
# z: -1.0406625270843506
# visibility: 0.9869875907897949
# , x: 0.515577495098114
# y: 0.18605941534042358
# z: -1.0409873723983765
# visibility: 0.9854230880737305
# , x: 0.57600998878479
# y: 0.21290847659111023
# z: -0.8762924075126648
# visibility: 0.9696042537689209
# , x: 0.4995470643043518
# y: 0.1886550486087799
# z: -0.8905598521232605
# visibility: 0.990659236907959
# , x: 0.5468488335609436
# y: 0.27893826365470886
# z: -0.9957324862480164
# visibility: 0.9933958649635315
# , x: 0.5193105340003967
# y: 0.27000588178634644
# z: -0.9998267292976379
# visibility: 0.9960113763809204
# , x: 0.613600492477417
# y: 0.4225468635559082
# z: -0.7366735339164734
# visibility: 0.9949216246604919
# , x: 0.4066463112831116
# y: 0.3555964231491089
# z: -0.7828637957572937
# visibility: 0.9955393671989441
# , x: 0.6086757779121399
# y: 0.6729733347892761
# z: -0.806006133556366
# visibility: 0.9896767735481262
# , x: 0.3483301103115082
# y: 0.6454815864562988
# z: -0.8704913854598999
# visibility: 0.9929355978965759
# , x: 0.569318413734436
# y: 0.944087028503418
# z: -0.9410374760627747
# visibility: 0.9236404895782471
# , x: 0.40536993741989136
# , x: 0.5817384123802185
# y: 0.9813061356544495
# z: 0.1013699397444725
# visibility: 0.8908438682556152
# , x: 0.46237215399742126
# y: 0.9583145380020142
# z: -0.09990997612476349
# visibility: 0.9516453742980957
# , x: 0.5538091063499451
# y: 1.2637392282485962
# z: 0.2371252328157425
# visibility: 0.35913586616516113
# , x: 0.4828372001647949
# y: 1.189444899559021
# z: -0.04588807374238968
# visibility: 0.5166828036308289
# , x: 0.5467203855514526
# y: 1.5364129543304443
# z: 0.7279056310653687
# visibility: 0.09388728439807892
# , x: 0.4473680555820465
# y: 1.5527797937393188
# z: 0.3304893672466278
# visibility: 0.2090078592300415
# , x: 0.5371109247207642
# y: 1.5785846710205078
# z: 0.768060028553009
# visibility: 0.13146771490573883
# , x: 0.41285285353660583
# y: 1.6105656623840332
# z: 0.36238664388656616
# visibility: 0.23177315294742584
# , x: 0.5787413716316223
# y: 1.703393578529358
# z: 0.6743034720420837
# visibility: 0.07671510428190231
# , x: 0.49520954489707947
# y: 1.7977313995361328
# z: 0.19785942137241364
# visibility: 0.1469411998987198
# ]

# %%
# 顯示前面那個圖有幾個特徵點（關節）
len(landmarks)
# Out:
# 33

# %%
# print each landmark
for lndmrk in mp_pose.PoseLandmark:
    print(lndmrk)
# Out:
# PoseLandmark.NOSE
# PoseLandmark.LEFT_EYE_INNER
# PoseLandmark.LEFT_EYE
# PoseLandmark.LEFT_EYE_OUTER
# PoseLandmark.RIGHT_EYE_INNER
# PoseLandmark.RIGHT_EYE
# PoseLandmark.RIGHT_EYE_OUTER
# PoseLandmark.LEFT_EAR
# PoseLandmark.RIGHT_EAR
# PoseLandmark.MOUTH_LEFT
# PoseLandmark.MOUTH_RIGHT
# PoseLandmark.LEFT_SHOULDER
# PoseLandmark.RIGHT_SHOULDER
# PoseLandmark.LEFT_ELBOW
# PoseLandmark.RIGHT_ELBOW
# PoseLandmark.LEFT_WRIST
# PoseLandmark.RIGHT_WRIST
# PoseLandmark.LEFT_PINKY
# PoseLandmark.RIGHT_PINKY
# PoseLandmark.LEFT_INDEX
# PoseLandmark.RIGHT_INDEX
# PoseLandmark.LEFT_THUMB
# PoseLandmark.RIGHT_THUMB
# PoseLandmark.LEFT_HIP
# PoseLandmark.RIGHT_HIP
# PoseLandmark.LEFT_KNEE
# PoseLandmark.RIGHT_KNEE
# PoseLandmark.LEFT_ANKLE
# PoseLandmark.RIGHT_ANKLE
# PoseLandmark.LEFT_HEEL
# PoseLandmark.RIGHT_HEEL
# PoseLandmark.LEFT_FOOT_INDEX
# PoseLandmark.RIGHT_FOOT_INDEX

# %% [markdown]
# 和上面的這行landmark的loop有關
#
#  Extract landmarks
#
#         try:
#             landmarks = results.pose_landmarks.landmark
#             print(landmarks)
#         except:
#             pass

# %%
landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value]
# Out:
# x: 0.44674092531204224
# y: 0.40473419427871704
# z: -0.483402818441391
# visibility: 0.9990031123161316

# %%
landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value]
# Out:
# x: 0.46774348616600037
# y: 0.8192567825317383
# z: -0.5908496975898743
# visibility: 0.9710184335708618

# %%
landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value]
# Out:
# x: 0.6292943954467773
# y: 1.0749990940093994
# z: -0.6004513502120972
# visibility: 0.906787633895874

# %% [markdown]
# # 3. Calculate Angles

# %% [markdown]
# arm curd 的關鍵點是 13

# %% [markdown]
# <img src="https://i.imgur.com/3j8BPdc.png" style="height:300px" >

# %%
def calculate_angle(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Mid
    c = np.array(c) # End
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle >180.0:
        angle = 360-angle
        
    return angle

# %% [markdown]
# adians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])這行
# 數據是前面的 cell 16-18 所跑出的 x 座標
#
# <img src="https://imgur.com/Wcd3BtT.png" style="height:300px" >

# %%
shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]

# %%
shoulder, elbow, wrist
# Out:
# ([0.44674092531204224, 0.40473419427871704],
#  [0.46774348616600037, 0.8192567825317383],
#  [0.6292943954467773, 1.0749990940093994])

# %%
calculate_angle(shoulder, elbow, wrist)
# Out:
# 150.62015684715183

# %%
tuple(np.multiply(elbow, [640, 480]).astype(int))
# Out:
# (299, 393)

# %%
cap = cv2.VideoCapture(0)
## Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # Make detection
        results = pose.process(image)
    
        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
            
            # Get coordinates
            shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
            elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            
            # Calculate angle
            angle = calculate_angle(shoulder, elbow, wrist)
            
            # Visualize angle
            cv2.putText(image, str(angle), 
                           tuple(np.multiply(elbow, [640,480]).astype(int)), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2, cv2.LINE_AA
                                )
            #print(landmarks)           
            
        except:
            pass
        
        
        # Render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) 
                                 )               
        
        cv2.imshow('Mediapipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # 4. Curl Counter

# %% [markdown]
# ### 右側

# %%
cap = cv2.VideoCapture(0)

# Curl counter variables
counter = 0 
stage = None

## Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # Make detection
        results = pose.process(image)
    
        # Recolor back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
            
            # Get coordinates
            shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
            elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            
            # Calculate angle
            angle = calculate_angle(shoulder, elbow, wrist)
            
            # Visualize angle
            cv2.putText(image, str(angle), 
                           tuple(np.multiply(elbow, [640, 480]).astype(int)), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2, cv2.LINE_AA
                                )
            
            # Curl counter logic
            if angle > 160:
                stage = "down"
            if angle < 30 and stage =='down':
                stage="up"
                counter +=1
                print(counter)
                       
        except:
            pass
        
        # Render curl counter
        # Setup status box
        cv2.rectangle(image, (0,0), (225,73), (245,117,16), -1)
        
        # Rep data
        cv2.putText(image, 'REPS', (15,12), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, str(counter), 
                    (10,60), 
                    cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)
        
        # Stage data
        cv2.putText(image, 'STAGE', (65,12), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, stage, 
                    (60,60), 
                    cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)
        
        
        # Render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) 
                                 )               
        
        cv2.imshow('Mediapipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### 影片

# %%
import cv2
import mediapipe as mp
import numpy as np

# Function to calculate angle
def calculate_angle(a, b, c):
    a = np.array(a)
    b = np.array(b)
    c = np.array(c)
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(np.degrees(radians))
    if angle > 180.0:
        angle = 360 - angle
    return angle

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# Video capture from file
cap = cv2.VideoCapture('/Users/peilinyang/Desktop/ArmCurd/1.mov')

# Curl counter variables
counter = 0
stage = None

while cap.isOpened():
    ret, frame = cap.read()

    if not ret:
        break

    # Recolor image to RGB
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False

    # Make detection
    results = pose.process(image)

    # Recolor back to BGR
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    # Extract landmarks
    try:
        landmarks = results.pose_landmarks.landmark

        # Get coordinates
        shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
        elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
        wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]

        # Calculate angle
        angle = calculate_angle(shoulder, elbow, wrist)

        # Visualize angle
        cv2.putText(image, str(angle),
                    tuple(np.multiply(elbow, [640, 480]).astype(int)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2, cv2.LINE_AA)

        # Curl counter logic
        if angle > 160:
            stage = "down"
        if angle < 30 and stage == 'down':
            stage = "up"
            counter += 1
            print(counter)

    except:
        pass

    # Render curl counter
    # Setup status box
    cv2.rectangle(image, (0, 0), (225, 73), (245, 117, 16), -1)

    # Rep data
    cv2.putText(image, 'REPS', (15, 12),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(image, str(counter),
                (10, 60),
                cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 255, 255), 2, cv2.LINE_AA)

    # Stage data
    cv2.putText(image, 'STAGE', (65, 12),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(image, stage,
                (60, 60),
                cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 255, 255), 2, cv2.LINE_AA)

    # Render detections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                              mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                              mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2)
                              )

    cv2.imshow('Mediapipe Feed', image)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1
# 2

# %% [markdown]
# ### 左右都可算

# %%
import cv2
import mediapipe as mp
import numpy as np

# Function to calculate angle
def calculate_angle(a, b, c):
    a = np.array(a)
    b = np.array(b)
    c = np.array(c)
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(np.degrees(radians))
    if angle > 180.0:
        angle = 360 - angle
    return angle

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

cap = cv2.VideoCapture(0)

# Hand counter variables
left_counter = 0
right_counter = 0
left_total_counter = 0
right_total_counter = 0
left_stage = None
right_stage = None

## Setup mediapipe instance
while cap.isOpened():
    ret, frame = cap.read()

    # Recolor image to RGB
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False

    # Make detection
    results = pose.process(image)

    # Recolor back to BGR
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    try:
        landmarks = results.pose_landmarks.landmark

        # Extract landmarks for the left hand
        left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
        left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
        left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

        # Extract landmarks for the right hand
        right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
        right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
        right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]

        # Calculate angle for the left hand
        angle_left = calculate_angle(left_shoulder, left_elbow, left_wrist)

        # Calculate angle for the right hand
        angle_right = calculate_angle(right_shoulder, right_elbow, right_wrist)

        # Visualize angle for the left hand
        cv2.putText(image, f"Left Leg Angle: {angle_left}", tuple(np.multiply(left_elbow, [1400, 480]).astype(int)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (245,66,230), 2, cv2.LINE_AA)

        # Visualize angle for the right hand
        cv2.putText(image, f"Right Leg Angle: {angle_right}", tuple(np.multiply(right_elbow, [480, 480]).astype(int)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2, cv2.LINE_AA)

        # Check the left hand angle 
        if angle_left is not None and angle_left > 160:
            left_stage = "down"
        if angle_left is not None and angle_left < 30 and left_stage == 'down':
            left_stage = "up"
            left_counter += 1
            left_total_counter += 1
            print(f"Left Hand Reps: {left_counter}")

        # Check the right hand angle 
        if angle_right is not None and angle_right > 160:
            right_stage = "down"
        if angle_right is not None and angle_right < 30 and right_stage == 'down':
            right_stage = "up"
            right_counter += 1
            right_total_counter += 1
            print(f"Right Hand Reps: {right_counter}")

    except:
        pass

    # Render hand counter
    # Setup status box
    cv2.rectangle(image, (0, 0), (460, 100), (245, 117, 16), -1)

    # Rep data for left hand
    cv2.putText(image, 'L-REPS', (15, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(image, str(left_counter),
                (15, 90),
                cv2.FONT_HERSHEY_SIMPLEX, 2, (245, 66, 230), 2, cv2.LINE_AA)

    # Stage data for left hand
    cv2.putText(image, 'L-STAGE', (125, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(image, left_stage,
                (125, 80),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

    # Rep data for right hand
    cv2.putText(image, 'R-REPS', (250, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(image, str(right_counter),
                (250, 90),
                cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 0, 0), 2, cv2.LINE_AA)

    # Stage data for right hand
    cv2.putText(image, 'R-STAGE', (350, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(image, right_stage,
                (350, 80),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

    # Render detections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

    cv2.imshow('Mediapipe Feed', image)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# Output final counters
print(f"Final Left Hand Reps: {left_counter}")
print(f"Final Right Hand Reps: {right_counter}")
# Out:
# Right Hand Reps: 1
# Left Hand Reps: 1
# Right Hand Reps: 2
# Right Hand Reps: 3
# Left Hand Reps: 2
# Left Hand Reps: 3
# Right Hand Reps: 4
# Right Hand Reps: 5
# Left Hand Reps: 4
# Final Left Hand Reps: 4
# Final Right Hand Reps: 5

# %% [markdown]
# ### 影片 左右

# %%
import cv2
import mediapipe as mp
import numpy as np

# Function to calculate angle
def calculate_angle(a, b, c):
    a = np.array(a)
    b = np.array(b)
    c = np.array(c)
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(np.degrees(radians))
    if angle > 180.0:
        angle = 360 - angle
    return angle

# Initialize MediaPipe Pose
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# Video capture from file
cap = cv2.VideoCapture('/Users/peilinyang/Desktop/ArmCurd/1.mov')

# Hand counter variables
left_counter = 0
right_counter = 0
left_total_counter = 0
right_total_counter = 0
left_stage = None
right_stage = None

## Setup mediapipe instance
while cap.isOpened():
    ret, frame = cap.read()

    # Check if the frame is not empty
    if not ret:
        break

    # Recolor image to RGB
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False

    # Make detection
    results = pose.process(image)

    # Recolor back to BGR
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    try:
        landmarks = results.pose_landmarks.landmark

        # Extract landmarks for the left hand
        left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
        left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
        left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

        # Extract landmarks for the right hand
        right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
        right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
        right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]

        # Calculate angle for the left hand
        angle_left = calculate_angle(left_shoulder, left_elbow, left_wrist)

        # Calculate angle for the right hand
        angle_right = calculate_angle(right_shoulder, right_elbow, right_wrist)

        # Visualize angle for the left hand
        cv2.putText(image, f"Left Leg Angle: {angle_left}", tuple(np.multiply(left_elbow, [1400, 480]).astype(int)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (245,66,230), 2, cv2.LINE_AA)

        # Visualize angle for the right hand
        cv2.putText(image, f"Right Leg Angle: {angle_right}", tuple(np.multiply(right_elbow, [480, 480]).astype(int)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2, cv2.LINE_AA)

        # Check the left hand angle 
        if angle_left is not None and angle_left > 160:
            left_stage = "down"
        if angle_left is not None and angle_left < 30 and left_stage == 'down':
            left_stage = "up"
            left_counter += 1
            left_total_counter += 1
            print(f"Left Hand Reps: {left_counter}")

        # Check the right hand angle 
        if angle_right is not None and angle_right > 160:
            right_stage = "down"
        if angle_right is not None and angle_right < 30 and right_stage == 'down':
            right_stage = "up"
            right_counter += 1
            right_total_counter += 1
            print(f"Right Hand Reps: {right_counter}")

    except:
        pass

    # Render hand counter
    # Setup status box
    cv2.rectangle(image, (0, 0), (460, 100), (245, 117, 16), -1)

    # Rep data for left hand
    cv2.putText(image, 'L-REPS', (15, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(image, str(left_counter),
                (15, 90),
                cv2.FONT_HERSHEY_SIMPLEX, 2, (245, 66, 230), 2, cv2.LINE_AA)

    # Stage data for left hand
    cv2.putText(image, 'L-STAGE', (125, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(image, left_stage,
                (125, 80),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

    # Rep data for right hand
    cv2.putText(image, 'R-REPS', (250, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(image, str(right_counter),
                (250, 90),
                cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 0, 0), 2, cv2.LINE_AA)

    # Stage data for right hand
    cv2.putText(image, 'R-STAGE', (350, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
    cv2.putText(image, right_stage,
                (350, 80),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

    # Render detections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=2),
                                mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

    cv2.imshow('Mediapipe Feed', image)

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Release the video capture object and close all windows
cap.release()
cv2.destroyAllWindows()

# Output final counters
print(f"Final Left Hand Reps: {left_counter}")
print(f"Final Right Hand Reps: {right_counter}")
# Out:
# Right Hand Reps: 1
# Right Hand Reps: 2
# Final Left Hand Reps: 0
# Final Right Hand Reps: 2
